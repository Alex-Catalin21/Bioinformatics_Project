# %% [markdown]
# # **Data Collection**
# ## Computational Drug Discovery, Download Bioactivity Data
# Real-life data project for portfolio. In detail, we will be building a ML model using the ChEMBL bioactivity data.

# %% [markdown]
# # ChEMBL Database
# The ChEMBL Database is a db that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76.000 documents, 1.2 million essays and the data spans 13.000 targets and 1.800 cells and 33.000 indications.

# %% [markdown]
# # Libraries used
# ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL DB.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Search for Target protein
#
# Target search for coronavirus

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# 3 are single protein, rest are organisms
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %% [markdown]
# # Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase(fourth entry)
#
# The fourth entry(target protein, coronavirus 3C-like proteinase) will be assigned to the selected_target variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for coronavirus 3C-like proteinase(CHEMBL3927) that are reported as IC50 values in nM(nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# the higher the standard_value, the worse the potency becomes, so we'll need one as low as possible(more amount of drug to produce the same inhibition at 50 to produce the same effect aka "take 5 mg of medication or 5 litres")

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# We're going to save the resulting bioactivity data to a CSV file bioactivity_data.csv

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# Add to drive
#
# Firstly mount GDrive into Colab so we can access our GDrive from Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# We will craete a data folder in Colab Notebook folder in GDrive

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/"
# Out:
# 'Breast Cancer EDA And Classification.ipynb'
# 'Breast Cancer prediction using ANN.ipynb'
# 'CN Sandu-Martinas.ipynb'
# 'Copie a blocnotesului 1_Introducere in COLAB_RO.ipynb'
# 'Copie a blocnotesului Homework 1 (1).ipynb'
# 'Copie a blocnotesului Homework 1.ipynb'
# 'Copie a blocnotesului lab9.ipynb'
#  data
#  dogs-vs-cats
# 'Identificare tesut canceros.ipynb'
# 'Intro to Keras with breast cancer data[ANN].ipynb'
# 'Keras with TensorFlow Course - FreeCodeCamp'
#  lab9.ipynb
#  ML_bioactivity_data.ipynb
#  ML_bioactivity_schisto_data.ipynb
#  ML_Exploratory_Data_Analysis.ipynb
# 'Proiect RN Dynamic Duo.ipynb'
# 'Stock Price Predictor.ipynb'
#  Untitled0.ipynb
# 'Untitled1 (1).ipynb'
#  Untitled1.ipynb

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 76
# -rw------- 1 root root 68258 Apr 29 15:36 bioactivity_data.csv
# -rw------- 1 root root  9112 Apr 26 18:46 bioactivity_preprocessed_data.csv

# %% [markdown]
# The CSV files for now

# %%
# !ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# we'll take a brief look at the bioactivity_data.csv file that was just created

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# # Taking care of missing data
# If any compounds has missing value for the standard_value column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# There's no missing data in this dataset. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# # Data pre-processing of the bioactivity data

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 bM will be considered to be active while those greater than 10.000 nM will be considered to be inactive. As for those values in between 1.000 and 10.000 nM will be referred to as intermediate.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Iterate the molecule_chembl_id to a list

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# Iterate canonical_smiles to a list
#
#
# *   btw this dataset is made of multiple compounds and a compound is a molecule which is a chemical structure that produces a modulatory activity(exerts some effect on a target protein) to produce a desired biological effect which ultimately cure symptoms
#
# *   Each compound will be described by a molecule chambl id so each will represent one compound and it's possible that multiple rows can have the same chamblid but for simplicity we'll keep just unique ones so no redundancy

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# Iterate standard_value to a list

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# Combine the 4 lists into a dataframe

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, standard_value, bioactivity_class))
df3 = pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class standard_value
# 0              7200.0   intermediate
# ...

# %% [markdown]
# # Alternative method(better)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %%
pd.concat([df3, pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value             0
# 0           7200.0  intermediate
# ...

# %% [markdown]
# Save dataframe to CSV

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 88
# -rw-r--r-- 1 root root 68258 Apr 29 15:36 bioactivity_data.csv
# -rw-r--r-- 1 root root  9112 Apr 29 15:37 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Apr 29 15:36 gdrive
# drwxr-xr-x 1 root root  4096 Apr 27 13:35 sample_data

# %% [markdown]
# Copy to the GDrive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
